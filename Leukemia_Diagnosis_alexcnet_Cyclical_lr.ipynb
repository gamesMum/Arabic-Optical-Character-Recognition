# %% [markdown]
# <a href="https://colab.research.google.com/github/gamesMum/Arabic-Optical-Character-Recognition/blob/master/Leukemia_Diagnosis_alexcnet_Cyclical_lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Leukemia Diagnostic Model
#
# **Classification of Acute Leukemia using Pretrained Deep Convolutional Neural Networks**
# Based on the implementation in the paper:
#
# [**Human-level recognition of blast cells in acute myeloid
# leukemia with convolutional neural networks**](https://www.biorxiv.org/content/10.1101/564039v1.full.pdf)
#
#  **The Dataset used in this implementation:**
#
#
# - The dataset is for AML instead of ALL
# -The number of classes are 10
#
# - link to the dataset https://www.kaggle.com/lsaa2014/single-cell-morphological-dataset-of-leukocytes

# %% [markdown]
# # **Materials and Methods**
#
# - peripheral blood smears were selected from 100 patients diagnosed with different subtypes
# of AML at the Laboratory of Leukemia Diagnostics at Munich University Hospital between 2014 and 2017, and smears from 100 patients found to exhibit no morphological
# features of hematological malignancies in the same time frame.
#
# - The resulting digitised data consisted of multiresolution pyramidal images of a size of approximately 1 GB per scanned area of interest.
# A trained examiner experienced in routine cytomorphological diagnostics at Munich University Hospital differentiated physiological and pathological leukocyte types contained
# in the microscopic scans into the classification scheme (see fig 2B),
# which is derived from standard morphological categories and was refined to take into account subcategories relevant for the morphological classification of AML, such as bilobed Promyelocytes, which are typical of the FAB subtype M3v.
# -  Annotation was carried out on a
# single-cell basis, and approximately 100 cells were differentiated in each smear
# - Subimage patches of size 400 x 400 pixels (corresponding to approximately 29µm x 29µm)
# around the annotated cells were extracted without further cropping or filtering, including
# background components such as erythrocytes, platelets or cell fragments.
# - When examining the screened blood smears, the cytologist followed the routine clinical procedure.
# Overall, 18,365 single-cell images were annotated and cut out of the scan regions.
#
# - Annotations of single-cell images provide the ground truth for training and evaluation
# of our network.
#
# - Morphological classes containing fewer than 10 images were merged with
# neighbouring classes of the taxonomy.
#
# - A subset of 1,905 single-cell images from all morphological categories were presented to a second, independent examiner, and annotated
# for a second time in order to estimate inter-rater variability
#
# **For Implementation:**
# -	The network was adopted  to input image dimensions of 400 x 400 x 3
# -	No further cropping or ﬁltering.
# -	Retained the cardinality hyper-parameter at C = 32.
# -	The ﬁnal dense layer adapted to our 10-category classiﬁcation scheme.
# -	Annotations of single-cell images provide the ground truth for training and evaluation of the network
# -	There are 10 classes for training and evaluation.
# -	For our image classiﬁcation task, we used a Alexnet
# -	The network was trained for at least 20 epochs, which took a computing time of approximately 4 days on a Nvidia GeForce GTX TITAN X GPU.
# -	The test group contains 20%, and the validation group 20% of the images
# -	Random rotational transformations of 0−359 degrees, as well as random horizontal and vertical ﬂips to the single-cell images in the dataset.
# -	In the end the data set was augmented in such a way that each class contained approximately 10,000 images for training. (This is from the origional paper that had 15 classes, but this number increased in this implementation since some of the classes were combined)
# - You'll see that we implemented a technique to choose and cycle between different learning rate values. This implementation is based on the paper by Leslie Smith here: https://arxiv.org/abs/1506.01186 and with the help of this great article by Thomas Dehaene
# https://towardsdatascience.com/adaptive-and-cyclical-learning-rates-using-pytorch-2bf904d18dee. More details found as you go along

# %%
# remove files 
# !rm -rf /content/AML-Cytomorphology_LMU_1

# %%
import json

# read file
with open('/content/kaggle.json', 'r') as myfile:
    data=myfile.read()
# parse file
obj = json.loads(data)
#get username and key
kaggle_key = str(obj['key'])
kaggle_username = str(obj['username'])

# %%
import os

# parse file
obj = json.loads(data)

os.environ['KAGGLE_USERNAME'] = kaggle_username # username from the json file
os.environ['KAGGLE_KEY'] = kaggle_key # key from the json file
# !kaggle datasets download -d "lsaa2014/single-cell-morphological-dataset-of-leukocytes" # api copied from kaggle
# Out:
# Downloading single-cell-morphological-dataset-of-leukocytes.zip to /content
# 100% 5.74G/5.74G [02:03<00:00, 34.7MB/s]
# 100% 5.74G/5.74G [02:03<00:00, 49.9MB/s]

# %%
#unzip the folder downloaded from kaggle
# !unzip 'single-cell-morphological-dataset-of-leukocytes.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3576.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3577.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3578.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3579.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3580.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3581.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3582.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3583.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3584.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3585.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3586.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3587.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3588.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3589.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3590.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3591.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3592.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3593.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3594.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3595.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3596.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3597.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3598.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3599.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3600.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3601.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3602.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3603.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3604.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3605.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3606.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3607.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3608.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3609.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3610.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3611.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3612.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3613.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3614.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3615.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3616.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3617.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3618.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3619.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3620.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3621.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3622.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3623.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3624.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3625.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3626.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3627.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3628.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3629.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3630.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3631.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3632.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3633.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3634.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3635.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3636.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3637.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3638.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3639.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3640.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3641.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3642.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3643.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3644.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3645.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3646.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3647.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3648.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3649.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3650.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3651.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3652.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3653.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3654.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3655.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3656.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3657.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3658.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3659.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3660.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3661.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3662.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3663.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3664.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3665.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3666.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3667.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3668.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3669.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3670.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3671.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3672.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3673.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3674.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3675.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3676.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3677.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3678.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3679.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3680.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3681.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3682.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3683.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3684.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3685.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3686.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3687.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3688.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3689.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3690.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3691.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3692.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3693.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3694.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3695.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3696.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3697.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3698.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3699.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3700.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3701.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3702.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3703.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3704.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3705.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3706.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3707.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3708.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3709.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3710.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3711.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3712.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3713.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3714.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3715.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3716.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3717.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3718.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3719.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3720.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3721.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3722.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3723.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3724.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3725.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3726.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3727.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3728.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3729.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3730.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3731.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3732.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3733.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3734.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3735.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3736.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3737.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3738.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3739.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3740.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3741.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3742.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3743.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3744.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3745.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3746.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3747.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3748.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3749.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3750.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3751.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3752.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3753.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3754.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3755.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3756.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3757.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3758.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3759.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3760.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3761.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3762.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3763.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3764.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3765.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3766.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3767.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3768.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3769.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3770.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3771.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3772.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3773.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3774.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3775.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3776.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3777.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3778.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3779.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3780.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3781.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3782.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3783.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3784.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3785.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3786.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3787.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3788.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3789.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3790.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3791.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3792.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3793.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3794.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3795.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3796.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3797.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3798.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3799.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3800.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3801.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3802.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3803.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3804.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3805.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3806.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3807.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3808.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3809.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3810.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3811.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3812.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3813.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3814.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3815.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3816.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3817.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3818.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3819.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3820.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3821.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3822.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3823.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3824.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3825.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3826.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3827.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3828.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3829.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3830.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3831.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3832.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3833.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3834.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3835.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3836.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3837.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3838.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3839.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3840.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3841.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3842.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3843.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3844.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3845.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3846.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3847.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3848.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3849.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3850.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3851.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3852.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3853.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3854.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3855.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3856.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3857.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3858.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3859.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3860.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3861.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3862.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3863.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3864.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3865.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3866.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3867.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3868.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3869.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3870.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3871.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3872.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3873.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3874.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3875.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3876.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3877.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3878.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3879.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3880.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3881.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3882.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3883.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3884.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3885.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3886.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3887.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3888.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3889.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3890.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3891.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3892.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3893.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3894.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3895.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3896.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3897.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3898.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3899.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3900.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3901.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3902.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3903.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3904.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3905.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3906.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3907.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3908.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3909.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3910.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3911.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3912.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3913.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3914.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3915.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3916.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3917.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3918.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3919.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3920.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3921.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3922.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3923.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3924.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3925.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3926.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3927.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3928.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3929.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3930.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3931.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3932.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3933.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3934.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3935.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3936.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3937.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3938.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3939.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3940.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3941.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3942.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3943.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3944.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3945.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3946.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3947.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3948.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3949.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3950.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3951.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3952.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3953.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3954.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3955.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3956.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3957.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3958.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3959.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3960.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3961.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3962.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3963.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3964.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3965.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3966.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3967.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3968.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3969.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3970.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3971.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3972.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3973.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3974.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3975.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3976.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3977.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3978.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3979.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3980.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3981.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3982.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3983.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3984.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3985.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3986.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3987.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3988.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3989.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3990.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3991.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3992.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3993.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3994.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3995.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3996.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3997.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3998.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_3999.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4000.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4001.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4002.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4003.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4004.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4005.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4006.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4007.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4008.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4009.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4010.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4011.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4012.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4013.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4014.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4015.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4016.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4017.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4018.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4019.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4020.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4021.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4022.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4023.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4024.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4025.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4026.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4027.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4028.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4029.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4030.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4031.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4032.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4033.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4034.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4035.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4036.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4037.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4038.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4039.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4040.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4041.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4042.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4043.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4044.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4045.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4046.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4047.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4048.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_4049.tiff
# ...
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8417.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8418.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8419.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8420.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8421.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8422.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8423.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8424.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8425.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8426.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8427.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8428.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8429.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8430.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8431.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8432.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8433.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8434.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8435.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8436.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8437.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8438.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8439.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8440.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8441.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8442.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8443.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8444.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8445.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8446.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8447.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8448.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8449.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8450.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8451.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8452.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8453.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8454.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8455.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8456.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8457.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8458.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8459.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8460.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8461.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8462.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8463.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8464.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8465.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8466.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8467.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8468.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8469.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8470.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8471.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8472.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8473.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8474.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8475.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8476.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8477.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8478.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8479.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8480.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8481.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8482.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8483.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/NGS/NGS_8484.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0001.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0002.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0003.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0004.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0005.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0006.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0007.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0008.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0009.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0010.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0011.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0012.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0013.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0014.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0015.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0016.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0017.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0018.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0019.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0020.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0021.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0022.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0023.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0024.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0025.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0026.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0027.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0028.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0029.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0030.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0031.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0032.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0033.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0034.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0035.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0036.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0037.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0038.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0039.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0040.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0041.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0042.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0043.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0044.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0045.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0046.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0047.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0048.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0049.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0050.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0051.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0052.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0053.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0054.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0055.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0056.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0057.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0058.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0059.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0060.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0061.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0062.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0063.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0064.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0065.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0066.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0067.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0068.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0069.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0070.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0071.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0072.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0073.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0074.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0075.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0076.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0077.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0078.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0079.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0080.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0081.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0082.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0083.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0084.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0085.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0086.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0087.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD/PMO/PMO_0088.tiff
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/Abbreviations.txt
#   inflating: blood_smear_images_for_aml_diagnosis_MOD/annotations.dat

# %%
#inporting the necessary libraries
import torch
from torch import nn
import numpy as np
from torchvision import transforms, datasets, models
import math
from tqdm import tqdm_notebook

# %%
#check if CUDA is available
train_on_gpu = torch.cuda.is_available()
if train_on_gpu:
    print("CUDA is available. Training on GPU!")
else:
    print("CUDA is not available. Training on CPU.")
# Out:
# CUDA is available. Training on GPU!

# %%
#time to prepare the data
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision as tv

batch_size = 32
test_size = 0.2
valid_size = 0.2

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]


#define the transforms
train_transform  = transforms.Compose([transforms.Resize((400,400)),
                                       transforms.RandomRotation(359),
                                       transforms.RandomHorizontalFlip(0.2),
                                       transforms.RandomVerticalFlip(0.2),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean=mean, std=std)])

test_transforms = transforms.Compose([transforms.Resize((400, 400)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=mean, std=std)])

train_data = datasets.ImageFolder("//content/blood_smear_images_for_aml_diagnosis_MOD/AML-Cytomorphology_LMU_MOD", transform = train_transform)

#obtain training indicies that will be used as testing and validation

num_train = len(train_data)
indicies = list(range(num_train))
np.random.shuffle(indicies)
split = int(np.floor(valid_size+test_size * num_train))
train_idx, test_idx, valid_idx = indicies[split:], indicies[:int(split/2)], indicies[int(split/2):split]
#define samplers for obtainig the trainig, testing and validation set
train_sampler = SubsetRandomSampler(train_idx)
test_sampler = SubsetRandomSampler(test_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           sampler = train_sampler)
test_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                          sampler = test_sampler)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                          sampler = valid_sampler)


#  PROMYELOCYTE (PMB Promyelocyte (bilobled))
# PMO Promyelocyte), MYELOCYTE (MYB Myelocyte, MYO Myeloblast)ARE FOUND ON LEUKEMIA PATIENTS 
classes = ['BAS', 'EBO', 'EOS', 'KSC','LYT','MON', 'MYO', 'NGB', 'NGS', 'PMO']

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt


def imshow(img):
  img = img /2+0.5 #unormalize the images
  plt.imshow(np.transpose(img, (1, 2, 0))) #convert it back from tensor to image

#get one batch of training images
dataiter = iter(train_loader) #now contains the first batch
images, labels = dataiter.next() #images=the first batch of images, labels= the first batch of labels
images = images.numpy() #convert the images to display them

#plot the imahes in the batch along with the corresponding labels
fig = plt.figure(figsize=(25,6))

for idx in np.arange(5):
  ax = fig.add_subplot(1, 5, idx+1, xticks=[], yticks=[]) #(rows, cols, index, .., ..)
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Load AlexNet pretrained model
model = models.alexnet(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(IntProgress(value=0, max=244418560), HTML(value='')))
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
#freeze the model calssifier
for param in model.parameters():
  param.requires_grad = False

from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(9216, 4608)),
                          ('relu', nn.ReLU()),
                          ('dropout', nn.Dropout(0.5)),
                          ('fc2', nn.Linear(4608, 2304)),
                          ('relu', nn.ReLU()),
                          ('dropout', nn.Dropout(0.5)),
                          ('fc3', nn.Linear(2304, 1024)),
                          ('relu', nn.ReLU()),
                          ('dropout', nn.Dropout(0.5)),
                         ('fc4', nn.Linear(1024, 512)),
                          ('relu', nn.ReLU()),
                          ('dropout', nn.Dropout(0.5)),
                          ('fc5', nn.Linear(512, 10)),
                          ('output', nn.LogSoftmax(dim=1) )                                       
                                      ]))

model.classifier = classifier

# %% [markdown]
# ## Implementing cyclic learning rate techneque:
# - implement the following experience to do so
# Refernce:
# - https://towardsdatascience.com/adaptive-and-cyclical-learning-rates-using-pytorch-2bf904d18dee
# - https://arxiv.org/pdf/1506.01186.pdf

# %% [markdown]
# ### Step 1: Finding the Upper and Lower Bound for The Learning rate
#
# - First we need to define an intial learning rate. Let say for example minimum of 1e-7
# and let the maximum be 0.1
# - Define an exponential schedule to run this step by step.
# - Here we are going to use LambdaLR scheduler fron Pytorch

# %%
# move model to GPU
if train_on_gpu:
    model.cuda()
model
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=9216, out_features=4608, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.5, inplace=False)
#     (fc2): Linear(in_features=4608, out_features=2304, bias=True)
#     (fc3): Linear(in_features=2304, out_features=1024, bias=True)
#     (fc4): Linear(in_features=1024, out_features=512, bias=True)
#     (fc5): Linear(in_features=512, out_features=10, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# Experiment parameters
lr_find_epochs = 2
start_lr = 1e-7
end_lr = 0.1

# %%
# LR function lambda
from torch.optim.lr_scheduler import LambdaLR
optimizer = torch.optim.SGD(model.parameters(), lr=start_lr)
criterion = nn.NLLLoss()

lr_lambda = lambda x: math.exp(x * math.log(end_lr / start_lr) / (lr_find_epochs * len( train_loader)))

scheduler = LambdaLR(optimizer, lr_lambda)

# %% [markdown]
# - In the following we run two epochs through the network. At each step we are capturing the LR and optimizing the gradient.

# %%
# Run the experiment
lr_find_loss = []
lr_find_lr = []

iter = 0

smoothing = 0.05
for i in range(lr_find_epochs):
  print("epoch {}".format(i))
  model.train()
  for inputs, labels in train_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
      inputs, labels = inputs.cuda(), labels.cuda()

    optimizer.zero_grad()
    
    # Get outputs to calc loss
    outputs = model(inputs)
    loss = criterion(outputs, labels)

    # Backward pass
    loss.backward()
    optimizer.step()

    # Update LR
    scheduler.step()
    lr_step = optimizer.state_dict()["param_groups"][0]["lr"]
    lr_find_lr.append(lr_step)

    # smooth the loss
    if iter==0:
      lr_find_loss.append(loss)
    else:
      loss = smoothing  * loss + (1 - smoothing) * lr_find_loss[-1]
      lr_find_loss.append(loss)
     
    iter += 1

# %%
plt.ylabel("loss")
plt.xlabel("learning rate")
plt.xscale("log")
plt.plot(lr_find_lr, lr_find_loss)
plt.show()

# %% [markdown]
# - From the figure above, For the upper bound (max). We won't pick the one on lowest point but rather about a factor of ten to the left (0.5 is the lowest point).
# In this case
# the lowest point is about 5e-1 so we'll take 5e-2
# - Now for the lowe bound (Min): Acording to the paper and other resouce a good lower bound is the upper divided by 6. So 5e-2/6 = 8e-3
#
# - This approach could also help us find the range of acceptable lr for our model even if we decided to go with a fixed lr.

# %%
# As concluded above
lr_max = 5e-2

# %% [markdown]
# ### Step 2: The CLR Scheduale
# Which varies the learning rate between uper and lower bound.
# we are going with triangular CLR schedule.
# ![triangular schedule](https://drive.google.com/file/d/1K6GraTrK4oV7GOokhFewG-xOmHqKbj75/view?usp=sharing)
# - Programatically we just need to create a custom function

# %%
def cyclical_lr(stepsize, min_lr=5e-2, max_lr=8e-3):

    # Scaler: we can adapt this if we do not want the triangular CLR
    scaler = lambda x: 1.

    # Lambda function to calculate the LR
    lr_lambda = lambda it: min_lr + (max_lr - min_lr) * relative(it, stepsize)

    # Additional function to see where on the cycle we are
    def relative(it, stepsize):
        cycle = math.floor(1 + it / (2 * stepsize))
        x = abs(it / stepsize - 2 * cycle + 1)
        return max(0, (1 - x)) * scaler(cycle)

    return lr_lambda

# %% [markdown]
# ### Step 3: Wrap it up
# - This can be wrapped up inside LamdaLR object in Pytorch

# %%
from torch import optim
#Parameters
factor = 6
end_lr = lr_max
iter = 0
total_logs = []

# move the model to GPU
if train_on_gpu:
    model.cuda()
model

#Loss function and optmixation function
criterion = nn.NLLLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1.)
step_size = 4*len(train_loader)
clr = cyclical_lr(step_size, min_lr=end_lr/factor, max_lr=end_lr)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, [clr])

# %% [markdown]
# # Step 4: Time to train our model

# %%
# number of epochs to train the model
import numpy as np
n_epochs = 50

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for images, labels in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, labels = images.cuda(), labels.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)
        # calculate the batch loss (comapre the values of the output model to the actual labels)
        loss = criterion(output, labels)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        
        scheduler.step() # > Where the magic happens
        lr_sched_test = scheduler.get_last_lr()
        # update training loss
        train_loss += loss.item()*images.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for images, labels in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, labels = images.cuda(), labels.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)
        # calculate the batch loss
        loss = criterion(output, labels)
        # update average validation loss 
        valid_loss += loss.item()*images.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        # print the decremnet in the validation
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tLearning rate: {}'.format(
            epoch, train_loss, valid_loss, lr_sched_test))
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min, 
        valid_loss))
        torch.save(model.state_dict(), 'model_AML_classifier.pt')
        valid_loss_min = valid_loss
    if epoch % 10 == 0:    
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tLearning rate: {}'.format(
            epoch, train_loss, valid_loss, lr_sched_test))

# %%
model.load_state_dict(torch.load('model_AML_classifier.pt'))

# %%
#initialize the test loss
test_loss = 0.0

class_correct = list(0. for i in range(10))
class_total = list (0. for i in range(10))

#set the model to test and validation mode (no gradient descent needed)
model.eval()

for data, target in test_loader:
  #move the tensor to GPU ig available
  if train_on_gpu:
    data, target = data.cuda(), target.cuda()
  #forward pass: compute prediction output by passing the first batch of test data
  output = model(data)
  #calculate the batch size
  loss = criterion(output, target)
  #update the test loss
  test_loss += loss.item()*data.size(0)
  #convert output probabilities to output class
  _, pred = torch.max(output, 1)
  #compare the prediction to true label
  correct_tensor = pred.eq(target.data.view_as(pred))
  #conveert to numpy array and remove the extra dimention and get only the result
  correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())

  #calculate test accuracy for each object class
  for i in range(batch_size):
    try:
      label = target.data[i] #get the corresponding label from the object
      class_correct[label] += correct[i].item()
      class_total[label] += 1
    except IndexError:
      break
  
# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
  if class_total[i] > 0:
     print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
  else:
       print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))

# %%
#Visualizing a sample tested of data
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

#Move model inputs to cuda
if train_on_gpu:
    images = images.cuda()

#get sample outputs
output = model(images)
#convert probabilties to prediction class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))

# %%
# Visualizing the result
# draw testing vs validation error
